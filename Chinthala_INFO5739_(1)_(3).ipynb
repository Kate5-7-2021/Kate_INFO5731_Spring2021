# %% [markdown]
# <a href="https://colab.research.google.com/github/Kate5-7-2021/Kate_INFO5731_Spring2021/blob/main/Chinthala_INFO5739_(1)_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df = pd.read_csv('/content/INFO5739_Vaccine distribution datacsv.csv')
# To display the top 5 rows
df.head(5)
# Out:
#   Countries and Regions  ...  Daily rate of doses administered
# 0                  U.S.  ...                         3020805.0
# 1                 China  ...                         3334571.0
# 2                 India  ...                         2560271.0
# 3                    EU  ...                         2423517.0
# 4                  U.K.  ...                          488411.0
#
# [5 rows x 6 columns]

# %%
# To display the bottom 5 rows
df.tail(5)
# Out:
#     Countries and Regions  ...  Daily rate of doses administered
# 184                 Libya  ...                               0.0
# 185            Kyrgyzstan  ...                               9.0
# 186               Armenia  ...                               0.0
# 187                 Tonga  ...                               0.0
# 188                 Nauru  ...                               0.0
#
# [5 rows x 6 columns]

# %%
df.dtypes
# Out:
# Countries and Regions                object
# Doses Administered                    int64
# Enough for % of People              float64
# % of people who got first dose      float64
# % of fully vaccinated people        float64
# Daily rate of doses administered    float64
# dtype: object

# %%
# Total number of rows and columns
df.shape
(189, 6)
# Rows containing duplicate data
duplicate_rows_df = df[df.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)
#no duplicate data
# Out:
# number of duplicate rows:  (0, 6)

# %%
# Finding the null values.
print(df.isnull().sum())
# Out:
# Countries and Regions               0
# Doses Administered                  0
# Enough for % of People              0
# % of people who got first dose      0
# % of fully vaccinated people        0
# Daily rate of doses administered    2
# dtype: int64

# %%
 df['Daily rate of doses administered'] = df['Daily rate of doses administered'].fillna(0)

# %%
from matplotlib.pyplot import figure

figure(figsize=(50, 40), dpi=80)

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (50,20)

# %%
df.plot(x='Countries and Regions',y='Doses Administered ')

# %%
df.plot(x='Countries and Regions',y='Enough for % of People',kind='bar')

# %%
df.plot(x='Countries and Regions',y='% of people who got first dose',kind='bar')
